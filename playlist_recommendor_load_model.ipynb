# %% [markdown]
# ### All imports needed for notebook

# %%
import os
import pickle as pk
import pandas as pd
import os

# -- local files
from modules import spotify_methods as sm
from modules import content_recommender as cr
from modules import recommender_methods as rm

# %% [markdown]
# # 1) Load Recommendations and Training Data

# %%
filename = os.getcwd() + "/model" + "/training_data.pkl"

with open(filename, 'rb') as fp:
    training_data = pk.load(fp)

# %% [markdown]
# # 2) Select a playlist and no of recommendations (max 1000)

# %%
select_pid = 201030
required_recommendations = 100

# %%
import json

with open("model/recommendations.json", "r") as f:
    playlist_recs = json.load(f)

# %%
selected_recommendations = (playlist_recs.get(str(select_pid))[0:required_recommendations])

# %% [markdown]
# # 3) Remove songs that are already in the playlist

# %%
orig_playlist = rm.show_playlist(select_pid, training_data)

# %%
selected_recommendations_flat = [item[0] if isinstance(item, list) else item for item in selected_recommendations]
de_duped_rec = rm.remove_known_positives(selected_recommendations_flat, orig_playlist)
